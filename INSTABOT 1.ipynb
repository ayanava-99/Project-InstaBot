# %% [markdown]
# # InstaBot Project - Part 1

# %% [markdown]
# ## (1)Login to your Instagram Handle
#
# ### (1.1)Submit with sample username and password

# %%
from selenium import webdriver
driver=webdriver.Chrome('C:/Users/Ayanava/Desktop/chromedriver')
driver.get('https://www.google.com')
driver.implicitly_wait(20)
a=driver.find_element_by_name('q')
a.send_keys('Instagram')
a.submit()
driver.implicitly_wait(5)
a=driver.find_element_by_class_name('ellip')
a.click()
driver.implicitly_wait(5)
a=driver.find_element_by_xpath('//button[contains(@class,"_0mzm-")]')
a.click()
driver.implicitly_wait(5)
a=driver.find_element_by_id('m_login_email')
a.send_keys('SAMPLE USERNAME')
a=driver.find_element_by_id('m_login_password')
a.send_keys('SAMPLE PASSWORD')
a=driver.find_element_by_name('login')
a.click()
a=driver.find_element_by_xpath('//button[contains(@class,"aOOlW")]')
a.click()

# %% [markdown]
# ## (2)Type for “food” in search bar and print all the names of the Instagram Handles that are displayed in list after typing “food”
#
# ### Note : Make sure to avoid printing hashtags

# %%
a=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]')
a.send_keys('food')
a=driver.find_elements_by_class_name('Ap253')
for i in a:
    val=i.text
    if val[0]=='#':
        print(val[1:])
        continue
    print(val)
# Out:
# foodporn
# food
# foodtalkindia
# food_lunatic
# foodnetwork
# yourfoodlab
# foodiesince96
# foodgod
# food
# foodmaniacindia
# foodofmumbai
# foodie_ank
# foodfusionpk
# foodie_lover_0
# foodiecouple_parvan
# foodys
# thisisdelhi
# joos.food
# foodafouti
# nepal.food
# foodbeast
# fooduz
# kolkatasutrafood
# meghnasfoodmagic
# mouthwaterfood
# thisisinsiderfood
# foodzaara
# mumbaifoodie
# tiktok_foodtravel
# foodieebybirth
# foodie_rushil
# foodie.snacks
# italian_food
# foods_etc
# mr.foodie_nepal
# foodrush.recipe
# love_food_extra
# whaaatislife
# food52
# food_ft_love
# fooddotcom
# foodbabyny
# foodvideo.s
# iamdatingfood
# kolkatafoodie
# street_food_chandigarh
# buzzfeedfood
# livingfoodz
# mumbaifoodjunkie
# foodyfetish
# foodie_incarnate
# food.kz
# foodelhi
# foods.nepal
# mtwfoodntravel
# foodie.doe
# delhidelites
# foodymanic
# foodie.bea
# foodfuly
# lipsmackingfood.pk
# foodieforeverandever23
# foodie.dada
# foodmapdelhi
# foodvbae
# stomach
# foodiebaniya
# ...

# %% [markdown]
# ## (3)Searching and Opening a profile using
#
# ### Open profile of “So Delhi”

# %%
a=driver.find_element_by_xpath('//div[contains(@class,"aIYm8")]')
a.click()
a=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]')
a.clear()
driver.implicitly_wait(10)
a.send_keys('So Delhi')
driver.implicitly_wait(10)
a=driver.find_element_by_class_name('Ap253')
a.click()

# %% [markdown]
# ## (4)Follow/Unfollow given handle -

# %% [markdown]
# ### (4.1) Open the Instagram Handle of “So Delhi”
# ### (4.2) Start following it. Print a message if you are already following

# %%
a=driver.find_element_by_xpath('//button[contains(@class,"_5f5mN")]')
a.click()
driver.implicitly_wait(5)

# %% [markdown]
# ### (4.3) After following, unfollow the instagram handle. Print a message if you have already unfollowed.

# %%
a=driver.find_element_by_xpath('//button[contains(@class,"_5f5mN")]')
a.click()
a=driver.find_element_by_xpath('//button[contains(@class,"aOOlW")]')
a.click()

# %% [markdown]
# ## (5)Like/Unlike posts

# %% [markdown]
# ### (5.1) Liking the top 30 posts of the ‘dilsefoodie'. Print message if you have already liked it.

# %%
import time
a=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]')
a.send_keys('dilsefoodie')
driver.implicitly_wait(5)
a=driver.find_element_by_class_name('Ap253')
a.click()
driver.implicitly_wait(5)
a=driver.find_elements_by_class_name('_9AhH0')
for i in range(5):
    driver.execute_script('window.scrollBy(0,1000);')
    time.sleep(1)
data=driver.find_elements_by_xpath('//div[contains(@class,"_9AhH0")]')
for j in range(5):
    driver.execute_script('window.scrollBy(0,-1000);')
    time.sleep(1)
driver.execute_script('window.scrollBy(0,500);')
k=0
final=len(data)
for i in range(final):
    data=driver.find_elements_by_xpath('//div[contains(@class,"_9AhH0")]')
    driver.execute_script('window.scrollBy(0,80);')
    k=k+1
    if k>30:
        break
    data[i].click()
    driver.implicitly_wait(4)
    a=driver.find_element_by_xpath('//span[contains(@class,"fr66n")]/button/span')
    a.click()
    driver.implicitly_wait(4)
    new=driver.find_element_by_xpath('//button[contains(@class,"ckWGn")]')
    new.click()

# %% [markdown]
# ### (5.2) Unliking the top 30 posts of the ‘dilsefoodie’. Print message if you have already unliked it.

# %%
import time
driver.execute_script('window.scrollBy(0,-1000);')
time.sleep(1)
driver.execute_script('window.scrollBy(0,500);')
k=0
final=len(data)
for i in range(final):
    data=driver.find_elements_by_xpath('//div[contains(@class,"_9AhH0")]')
    driver.execute_script('window.scrollBy(0,80);')
    k=k+1
    if k>30:
        break
    data[i].click()
    driver.implicitly_wait(4)
    a=driver.find_element_by_xpath('//span[contains(@class,"fr66n")]/button/span')
    a.click()
    driver.implicitly_wait(4)
    new=driver.find_element_by_xpath('//button[contains(@class,"ckWGn")]')
    new.click()

# %% [markdown]
# ## (6)Extract list of followers

# %% [markdown]
# ### (6.1) Extract the usernames of the first 500 followers of ‘foodtalkindia’ and ‘sodelhi’.

# %%
## USERNAMES OF foodtalkindia 

import time
k=1
a=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]')
a.send_keys('foodtalkindia')
driver.implicitly_wait(10)
a=driver.find_element_by_xpath('//span[contains(@class,"Ap253")]')
a.click()
driver.implicitly_wait(10)
a=driver.find_element_by_xpath('//a[contains(@class,"-nal3")]')
a.click()
driver.implicitly_wait(10)
for i in range(final):
    if k>500:
        break
    data=driver.find_elements_by_xpath('//a[contains(@class,"FPmhX")]')
    driver.execute_script('arguments[0].scrollIntoView(0,100);',driver.find_element_by_xpath('//ul[contains(@class,"jSC57")]'))
    driver.implicitly_wait(10)
    final=len(data)
    print(data[i].text)
    k=k+1
data=driver.find_element_by_xpath('//span[contains(@class,"glyphsSpriteX__outline__24__grey_9")]')
data.click()
# Out:
# ajay_singh_khangarot_th.akoda
# beardwithlens
# greatindiashowcom
# rita59431
# nlucieneferreirado
# daraerri
# kangscookingcorner
# sonu_sahab11015
# apeksha_00a
# aatish_sawant25
# chefandreamura
# roma_pal
# kabhi.kabhi.aditi._
# bazana.in
# hangoutsandfoods
# sumi_it_4411
# meera_midha
# mr._mani__143
# alou.lox
# nono_alijnjfh
# raishab_8055
# as_if7596
# mamtagupta19
# romillamasih
# mohd_sameer_82
# archananagar01
# brandbull
# foodiehaqse
# devsharma212
# anuradha.ghosh.714
# nishchay_not_nischay
# anythingforfood_
# the_food_tree
# wtfnavimumbai
# apna_kirana
# jatinduamr.d
# thebestion_localguide
# tanaya_ahluwalia
# guptameenal
# foodbygrumpyandlost
# extra_kamina_ayushu_
# anki.goel14
# clicknburp
# _messy.bun._
# foodie_modak
# sidharthsaini88
# mahdi_i10
# boardingsuitcases
# nsam.0
# that.quiet.girl_
# banjaariii
# unknown__dude_
# teddiah_b
# the_queen_came
# aashraygulati18
# labelladam
# resortshangrila
# mr_singh.0
# kentwalker8962
# escapetoknowwhere
# ...

# %%
## USERNAMES OF sodelhi 

import time
k=1
a=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]')
a.send_keys('sodelhi')
driver.implicitly_wait(10)
a=driver.find_element_by_xpath('//span[contains(@class,"Ap253")]')
a.click()
driver.implicitly_wait(10)
a=driver.find_element_by_xpath('//a[contains(@class,"-nal3")]')
a.click()
for i in range(final):
    if k>500:
        break
    data=driver.find_elements_by_xpath('//a[contains(@class,"FPmhX")]')
    driver.execute_script('arguments[0].scrollIntoView(0,100);',driver.find_element_by_xpath('//ul[contains(@class,"jSC57")]'))
    driver.implicitly_wait(10)
    final=len(data)
    print(data[i].text)
    k=k+1
data=driver.find_element_by_xpath('//span[contains(@class,"glyphsSpriteX__outline__24__grey_9")]')
data.click()
# Out:
# sanely_in.sane
# imranansari4361
# a.k.p.h.a.n
# shwetasharmabatra
# aparnateki
# shwetapawaria
# cj_ghoost___pushing_to_conquer
# kanishq_besoya_dilli
# ricksumlama8319
# yash._.02
# r_o_h_a_n_chauhan
# juhi_pai
# just_click5262
# zamidaar_gaama_ka
# er.twinkle
# mayank8581
# harshpanditsharma
# gunjankohli7
# pahaadan_girl25
# gkj3233
# ssimran_01
# the.road.yash.travelled
# djvarun46
# apeksha_00a
# general_machine
# roshmita.dey
# vijay_kr_amdahi_gonda
# 0abhinav_gupta0
# karanitsme
# tmadan07
# pullbabu
# chatorijodi
# naatkiraat
# _shivimaheshwari_
# farhaabdulmannan5
# alisha_210416
# raman131
# galinarestaurant
# mucool__bhayana
# vibsaneja
# sameersingh712
# sarikaguptaaa
# v_kriti
# travelerraghav
# wadhwani234
# akankashabhatia
# arindambasak55
# yasogamya_official
# vedantshaarma
# ankitraidhiman
# _.thevirgolady._
# miss_sharn7
# yo___studio
# tanyamanda5482
# zabihullah2332
# manav_bhora
# suman989657
# the_additya_malhotra
# goravroy
# nich._.eli18
# ...

# %% [markdown]
# ### (6.2) Now print all the followers of “foodtalkindia” that you are following but those who don’t follow you.

# %%
import time
k=1
a=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]')
a.send_keys('foodtalkindia')
driver.implicitly_wait(5)
a=driver.find_element_by_xpath('//span[contains(@class,"Ap253")]')
a.click()
driver.implicitly_wait(5)
a=driver.find_element_by_xpath('//a[contains(@class,"-nal3")]')
a.click()
driver.implicitly_wait(5)
data=driver.find_elements_by_xpath('//a[contains(@class,"FPmhX")]')
final=len(data)
for i in range(final):
    if k>500:
        break
    data=driver.find_elements_by_xpath('//a[contains(@class,"FPmhX")]')
    new_data=driver.find_elements_by_xpath('//button[contains(@class,"L3NKy")]')
    driver.execute_script('arguments[0].scrollIntoView(0,100);',driver.find_element_by_xpath('//ul[contains(@class,"jSC57")]'))
    driver.implicitly_wait(10)
    final=len(data)
    if new_data[i].text=='Following':
        print(data[i].text)
    k=k+1
data=driver.find_element_by_xpath('//span[contains(@class,"glyphsSpriteX__outline__24__grey_9")]')
data.click()
# Out:
# kangscookingcorner
# bazana.in
# hangoutsandfoods
# foodiehaqse
# wtfnavimumbai
# apna_kirana
# thebestion_localguide
# clicknburp
# _messy.bun._
# foodie_modak
# mahdi_i10
# boardingsuitcases
# banjaariii

# %% [markdown]
# ## (7)Check the story of ‘coding.ninjas’. Consider the following Scenarios and print error messages accordingly -
#
# ### (7.1)If You have already seen the story.
# ### (7.2)Or The user has no story.
# ### (7.3)Or View the story if not yet seen.

# %%
a=driver.find_element_by_xpath('//input[contains(@class,"XTCLo")]')
a.send_keys('coding.ninjas')
a=driver.find_element_by_xpath('//span[contains(@class,"Ap253")]')
a.click()
print('Not checking the story yet and now i am going to check it')
a=driver.find_element_by_xpath('//img[contains(@class,"_6q-tv")]')
a.click()
# Out:
# Not checking the story yet and now i am going to check it
